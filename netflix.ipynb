# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
netflix_data = pd.read_csv(r"C:\Users\parka\OneDrive\Desktop\priyapy\Netflix dataset analysis\Netflix Dataset.csv")

# %%
netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
netflix_data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix_data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
netflix_data.shape #total number of rows and columns
# Out:
# (7789, 11)

# %%
netflix_data.size
# Out:
# 85679

# %%
netflix_data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
netflix_data.dtypes  #data type of each columns
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
netflix_data.info()  #shows indexes, column types, memory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
netflix_data[netflix_data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#deleting duplicate rows

netflix_data.drop_duplicates(inplace = True)
netflix_data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix_data.shape
# Out:
# (7787, 11)

# %%
netflix_data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
netflix_data.isnull().sum()  #shows count of null values in each columns
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(netflix_data.isnull())
# Out:
# <AxesSubplot:>

# %%
netflix_data['Cast'].replace(np.nan, 'No Data', inplace=True)
netflix_data['Director'].replace(np.nan, 'No Data', inplace=True)

# %%
netflix_data.isnull().sum()
# Out:
# Show_Id           0
# Category          0
# Title             0
# Director          0
# Cast              0
# Country         507
# Release_Date     10
# Rating            7
# Duration          0
# Type              0
# Description       0
# dtype: int64

# %%
netflix_data['Country']=netflix_data['Country'].fillna(netflix_data['Country'].mode()[0])
netflix_data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0               No Data  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix_data['Date']=pd.to_datetime(netflix_data['Release_Date'])

# %%
netflix_data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date            datetime64[ns]
# dtype: object

# %%
netflix_data.isnull().sum()
# Out:
# Show_Id          0
# Category         0
# Title            0
# Director         0
# Cast             0
# Country          0
# Release_Date    10
# Rating           7
# Duration         0
# Type             0
# Description      0
# Date            10
# dtype: int64

# %%
netflix_data.dropna(inplace=True)

# %%
netflix_data.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# Date            0
# dtype: int64

# %%
netflix_data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            No Data
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %% [markdown]
# <h2> 1. How many Tv shows and movies in this dataset?show with the bar graph</h2>

# %%
netflix_data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5372
# TV Show    2398
# Name: Category, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
ax=sns.countplot(netflix_data['Category'])

for p in ax.patches:
   ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

plt.show()
# Out:
# C:\python 3.9\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <h2> 2. Shows 'Dangal' movies data </h2>

# %%
netflix_data[netflix_data['Title'].isin(['Dangal'])]   #shows particular item record in column
# Out:
#      Show_Id Category   Title       Director  \
# 1595   s1596    Movie  Dangal  Nitesh Tiwari
#
#                                                    Cast Country  \
# 1595  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...   India
#
#        Release_Date Rating Duration  \
# 1595  June 21, 2017  TV-PG  161 min
#
#                                              Type  \
# 1595  Dramas, International Movies, Sports Movies
#
#                                             Description       Date
# 1595  A once-promising wrestler pursues the gold med... 2017-06-21

# %% [markdown]
# <h2>3. In which year highest no. of TV shows and Movies were Released and show with bar graph</h2>

# %%
netflix_data['Date'].dt.year.value_counts()  #counts no. of movies released in all years Using Date Column
# Out:
# 2019    2153
# 2020    2009
# 2018    1684
# 2017    1222
# 2016     440
# 2021     117
# 2015      88
# 2014      25
# 2011      13
# 2013      11
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# Name: Date, dtype: int64

# %%
netflix_data['Date'].dt.year.value_counts().plot(kind='barx`')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2> 4. Shows all movies that was released in year 2010 </h2>

# %%
 netflix_data['Year']=netflix_data['Date'].dt.year #creating new column for showing year 2020 data

# %%
netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            No Data
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Year'] == 2020)] #flitering and used and operator (for view count use count method)
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Year'] == 2020) & (netflix_data['Country'] == 'India')]

#showing only Indian Movies
# Out:
#      Show_Id Category                        Title                   Director  \
# 244     s245    Movie            A truthful Mother  Ravishankar Venkateswaran
# 270     s271    Movie                  Aapla Manus             Satish Rajwade
# 300     s301    Movie               Action Replayy        Vipul Amrutlal Shah
# 343     s344    Movie                    Agneepath                Mukul Anand
# 356     s357    Movie                       Aiyyaa           Sachin Kundalkar
# ...      ...      ...                          ...                        ...
# 7565   s7564    Movie                What the Fish             Gurmmeet Singh
# 7576   s7575    Movie         What's Your Raashee?         Ashutosh Gowariker
# 7667   s7666    Movie           World Famous Lover             Kranthi Madhav
# 7703   s7702    Movie                   Yeh Ballet         Sooni Taraporevala
# 7746   s7745    Movie  Yours Sincerely, Kanan Gill               Neville Shah
#
# ...

# %% [markdown]
# <h2> 5. Show indian Tv shows titles </h2>

# %%
netflix_data[(netflix_data['Category'] == 'TV Show') & (netflix_data['Country'] == 'India')] ['Title'] #showing perticular column related result only
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
netflix_data['Director'].value_counts().head(10)
# Out:
# No Data                   2375
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Jay Chapman                 12
# Steven Spielberg            10
# David Dhawan                 9
# Name: Director, dtype: int64

# %% [markdown]
# <h2> 6. Shows all the India records ,category is movie and type is comedies</h2>

# %%
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Type'] == 'Comedies') | (netflix_data['Country'] == 'India')]

#Using AND , OR operators
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %% [markdown]
# <h2>7. In how many movies/shows Tom Cruise was cast?</h2>

# %%
netflix_data [netflix_data['Cast'].str.contains('Tom Cruise')]  

#netflix_data[netflix_data['cast']=='Tom cruise'] is not worked bcoz there is multiple records in Cast column
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       Date  Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %% [markdown]
# <h2> 8.What are different ratings defined by netflix? </h2>

# %%
netflix_data["Rating"].nunique()
# Out:
# 14

# %%
netflix_data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y',
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# <h2> 9.How many movies got TV-14 rating in India </h2>

# %%
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Rating'] == 'TV-14')].shape
# Out:
# (1272, 13)

# %%
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Rating'] == 'TV-14') & (netflix_data['Country'] == 'United States')]
# Out:
#      Show_Id Category                                     Title  \
# 33       s34    Movie                              #realityhigh
# 47       s48    Movie                             1 Mile to You
# 56       s57    Movie  100 Years: One Woman's Fight for Justice
# 184     s185    Movie    A Haunting at Silver Falls: The Return
# 223     s224    Movie                             A Secret Love
# ...      ...      ...                                       ...
# 7571   s7570    Movie               What Would Sophia Loren Do?
# 7588   s7587    Movie                         When We First Met
# 7644   s7643    Movie                                  Wish Man
# 7658   s7657    Movie             Wonho Chung: Live in New York
# 7664   s7663    Movie                                   Work It
#
#               Director                                               Cast  \
# 33    Fernando Lebrija  Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...

# %%
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Rating'] == 'TV-14') & (netflix_data['Country'] == 'India')].shape
# Out:
# (497, 13)

# %% [markdown]
# <h2> 10. How many TV shows got the 'R' rating, after 2015 year? </h2>

# %%
netflix_data[(netflix_data['Category'] =='TV Show') & (netflix_data['Rating'] == 'R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel            No Data
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast        Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...         Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  United States
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description       Date  Year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016
# ...

# %%
netflix_data[(netflix_data['Category'] =='TV Show') & (netflix_data['Rating'] == 'R') & (netflix_data['Year'] > 2015)]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel            No Data
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast        Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...         Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  United States
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description       Date  Year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016
# ...

# %% [markdown]
# <h2> 11. What is maximum duration of movies/tv show on netflix? </h2>

# %%
netflix_data['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '113 min', '114 min', '130 min',
#        '94 min', '140 min', '135 min', '82 min', '70 min', '121 min',
#        '92 min', '164 min', '53 min', '83 min', '116 min', '86 min',
#        '120 min', '96 min', '126 min', '129 min', '77 min', '137 min',
#        '148 min', '28 min', '122 min', '176 min', '85 min', '22 min',
#        '68 min', '111 min', '29 min', '142 min', '168 min', '21 min',
#        '59 min', '20 min', '98 min', '108 min', '76 min', '26 min',
# ...

# %%
netflix_data.Duration.dtype
# Out:
# dtype('O')

# %%
netflix_data[['Minute' , 'unit']] = netflix_data['Duration'].str.split(' ', expand = True)
netflix_data.head(20)   #minutes and units well be seprated
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%               No Data
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983               No Data
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09               No Data
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
netflix_data=netflix_data.astype({'Minute': 'int32'})  #change the minutes data type

# %%
netflix_data['Minute'].max() # maximum minutes
# Out:
# 312

# %%
netflix_data['Minute'].min() #Minimum minutes
# Out:
# 1

# %%
netflix_data['Minute'].mean()
# Out:
# 69.21840411840412

# %% [markdown]
# <h2> 11. Which individual country has the highest no. of TV Shows? </h2>

# %%
tv_show=netflix_data[netflix_data['Category'] == 'TV Show']

# %%
tv_show.sort_index(axis = 1)
# Out:
#                                                    Cast Category  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...  TV Show
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  TV Show
# 11    Robert Więckiewicz, Maciej Musiał, Michalina O...  TV Show
# 12                                              No Data  TV Show
# 16    Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...  TV Show
# ...                                                 ...      ...
# 7769  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...  TV Show
# 7777  Kensho Ono, Takahiro Sakurai, Mikako Komatsu, ...  TV Show
# 7779                                            No Data  TV Show
# 7781  Manu NNa, Ana Julia Yeyé, Ray Contreras, Pablo...  TV Show
# 7787                         Adriano Zumbo, Rachel Khoo  TV Show
#
#                     Country       Date  \
# 0                    Brazil 2020-08-14
# 5                    Turkey 2017-07-01
# 11    Poland, United States 2018-11-30
# ...

# %%
tv_show.reset_index()
# Out:
#       index Show_Id Category                  Title              Director  \
# 0         0      s1  TV Show                     3%               No Data
# 1         5      s6  TV Show                     46           Serdar Akar
# 2        11     s12  TV Show                   1983               No Data
# 3        12     s13  TV Show                   1994  Diego Enrique Osorno
# 4        16     s17  TV Show                 Feb-09               No Data
# ...     ...     ...      ...                    ...                   ...
# 2393   7769   s7768  TV Show     Zindagi Gulzar Hai               No Data
# 2394   7777   s7776  TV Show             Zoids Wild               No Data
# 2395   7779   s7778  TV Show            Zombie Dumb               No Data
# 2396   7781   s7780  TV Show              Zona Rosa               No Data
# 2397   7787   s7786  TV Show  Zumbo's Just Desserts               No Data
#
#                                                    Cast  \
# ...

# %%
tv_show.Country.value_counts()
# Out:
# United States                                                975
# United Kingdom                                               203
# Japan                                                        155
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %%
tv_show.Country.value_counts().head(1)
# Out:
# United States    975
# Name: Country, dtype: int64

# %% [markdown]
# <h2> 12.Sort the dataset by year </h2>

# %%
tv_show.sort_values(by='Year').head(20)
# Out:
#      Show_Id Category                         Title     Director  \
# 1765   s1766  TV Show               Dinner for Five      No Data
# 1089   s1090  TV Show                  Breaking Bad      No Data
# 6057   s6057  TV Show                      The 4400      No Data
# 2503   s2504  TV Show                   Gossip Girl      No Data
# 3098   s3099  TV Show                   Jack Taylor  Stuart Orme
# 5313   s5313  TV Show  Russell Peters vs. the World      No Data
# 6631   s6630  TV Show          The Magic School Bus      No Data
# 2498   s2499  TV Show                    Goosebumps      No Data
# 4811   s4812  TV Show           Pee-wee's Playhouse      No Data
# 6158   s6158  TV Show                   The Borgias      No Data
# 3643   s3644  TV Show                    Lilyhammer      No Data
# 7522   s7521  TV Show                         Weeds      No Data
# 4685   s4686  TV Show                 Oscar's Oasis      No Data
# ...

# %%
tv_show.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                         Title     Director  \
# 1864   s1865  TV Show           Dream Home Makeover      No Data
# 2753   s2754  TV Show        History of Swear Words      No Data
# 6636   s6635  TV Show                 The Magicians      No Data
# 4390   s4391  TV Show             Nailed It! Mexico      No Data
# 1780   s1781  TV Show                Disenchantment      No Data
# ...      ...      ...                           ...          ...
# 3098   s3099  TV Show                   Jack Taylor  Stuart Orme
# 1089   s1090  TV Show                  Breaking Bad      No Data
# 2503   s2504  TV Show                   Gossip Girl      No Data
# 5313   s5313  TV Show  Russell Peters vs. the World      No Data
# 1765   s1766  TV Show               Dinner for Five      No Data
#
#                                                    Cast  \
# 1864                                            No Data
# 2753                                       Nicolas Cage
# ...
